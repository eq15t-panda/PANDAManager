# %%
import sys, os
print(sys.executable)
print(os.getcwd())
# Out:
# /home/panda/miniconda3/envs/pyrpl_env/bin/python
# /home/panda/PycharmProjects/PANDAManager

# %%
import os
os.chdir("/home/panda/PycharmProjects/PyRPLSetup/pyrpl")
print(os.getcwd())
# Out:
# /home/panda/PycharmProjects/PyRPLSetup/pyrpl

# %%
import pyrpl
# Out:
# ...
# /home/panda/miniconda3/envs/pyrpl_env/lib/python3.9/site-packages/paramiko/transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
p = pyrpl.Pyrpl("RP_sweep.yml")
# p = pyrpl.Pyrpl("Lock_SHG.yml")
# Out:
# INFO:pyrpl:All your PyRPL settings will be saved to the config file
#     /home/panda/pyrpl_user_dir/config/RP_sweep.yml
# If you would like to restart PyRPL with these settings, type "pyrpl.exe RP_sweep" in a windows terminal or
#     from pyrpl import Pyrpl
#     p = Pyrpl('RP_sweep')
# in a python terminal.
# INFO:pyrpl.redpitaya:Successfully connected to Redpitaya with hostname 192.168.1.100.
# QLayout::addChildLayout: layout "" already has a parent

# %%
# Sweep RedPitaya for lock
rp = pyrpl.Pyrpl('RP_sweep.yml')
